# %% [markdown]
# # DATA 607 -- Assignment 3
# ## Graeme Kempthorne, 30130245

# %% [markdown]
# In this assignment, we apply the ideas underlying dense word embeddings like Word2Vec and GloVe to construct dense embeddings of categorical features.
#
# The context of our exploration will be the [Rossmann Store Sales Competition](https://www.kaggle.com/c/rossmann-store-sales/overview/description) from *Kaggle*, the goal of which is to forecast store sales using store, promotion, and competitor data.

# %% [markdown]
# ## Instructions
#
# 1. Download the data from the competition page or from [my github](https://github.com/mgreenbe/rossmann).
#
# 2. Replace each date in the `Date` column with number of days between it and January 1, 2013, the earliest date in the table.
#
# 3. Use `pd.get_dummies` to construct dataframes `stores`, `days_of_week`, and `state_holidays` containing 1-hot encodings of the categorical variables `Store`, `DayOfWeek`, and `StateHoliday`, respectively.
#
# 4. Assemble these encoded features, together with the numerical ones (`Date`, `Customers`) and binary ones (`Open`, `Promo`, `SchoolHoliday`), in a matrix `X`, the first 1115 columns of which represent the store ID.
#
# 5. Split the data `X` and `Y` into training and validation sets. Standardize the numerical feature columns. Here, the relevant means and standard deviations should be computed from *training data*.
#
# 6. Train the model `MyModel`, below, using `MeanSquaredLogarithmicError` as the loss function. Explain, briefly, why this is an appropriate choice of loss function. Stop training when validation error stabilizes.
#
# 7. **(Optional)** Add hidden layers to this model and tune the `store_emb_dim` hyperparameter to improve your results.

# %% [markdown]
# #1

# %%
from google.colab import drive
import tensorflow as tf
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

drive.mount('/content/drive/')
df_main = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/rossmann-main/store.csv")
df_sample = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/rossmann-main/sample_submission.csv")
df_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/rossmann-main/test.csv")
df_train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/rossmann-main/train.csv")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# #2

# %%
df_train['Date'] = pd.to_datetime(df_train['Date'])
df_train['Date'] = df_train['Date'] - pd.to_datetime('2013-01-01')
df_train['Date'] = df_train['Date'] / pd.Timedelta(1, unit='d')
df_train['Date']= df_train['Date'].astype('int')
df_train
# Out:
#          Store  DayOfWeek  Date  Sales  ...  Open  Promo  StateHoliday SchoolHoliday
# 0            1          5   941   5263  ...     1      1             0             1
# 1            2          5   941   6064  ...     1      1             0             1
# 2            3          5   941   8314  ...     1      1             0             1
# 3            4          5   941  13995  ...     1      1             0             1
# 4            5          5   941   4822  ...     1      1             0             1
# ...        ...        ...   ...    ...  ...   ...    ...           ...           ...
# 1017204   1111          2     0      0  ...     0      0             a             1
# 1017205   1112          2     0      0  ...     0      0             a             1
# 1017206   1113          2     0      0  ...     0      0             a             1
# 1017207   1114          2     0      0  ...     0      0             a             1
# 1017208   1115          2     0      0  ...     0      0             a             1
#
# [1017209 rows x 9 columns]

# %%
df_train_sample = df_train.sample(n=10000, random_state=42)
df_train_sample
# Out:
#         Store  DayOfWeek  Date  Sales  ...  Open  Promo  StateHoliday SchoolHoliday
# 76435     616          7   873      0  ...     0      0             0             0
# 923026    592          2    84   5548  ...     1      1             0             1
# 731180    526          6   256   7467  ...     1      0             0             0
# 790350    601          2   203   3360  ...     1      0             0             1
# 252134    953          1   713  11414  ...     1      1             0             0
# ...       ...        ...   ...    ...  ...   ...    ...           ...           ...
# 319724    160          5   640      0  ...     0      1             a             0
# 356752    832          1   601   4933  ...     1      0             0             1
# 912066    782          5    94   4491  ...     1      0             0             1
# 448301    857          1   510   6055  ...     1      0             0             0
# 507993    339          3   456   5597  ...     1      1             0             0
#
# [10000 rows x 9 columns]

# %% [markdown]
# # 3

# %%
df_train_all = pd.get_dummies(df_train_sample, columns=['Store','DayOfWeek','StateHoliday'])
df_train_all
# Out:
#         Date  Sales  Customers  ...  StateHoliday_a  StateHoliday_b  StateHoliday_c
# 76435    873      0          0  ...               0               0               0
# 923026    84   5548        710  ...               0               0               0
# 731180   256   7467       1150  ...               0               0               0
# 790350   203   3360        323  ...               0               0               0
# 252134   713  11414        853  ...               0               0               0
# ...      ...    ...        ...  ...             ...             ...             ...
# 319724   640      0          0  ...               1               0               0
# 356752   601   4933        448  ...               0               0               0
# 912066    94   4491        425  ...               0               0               0
# 448301   510   6055        781  ...               0               0               0
# 507993   456   5597        720  ...               0               0               0
#
# [10000 rows x 1133 columns]

# %% [markdown]
# #4

# %%
#combining all of the predictor variables
X = df_train_all.iloc[:,6:-1]
X = pd.concat([X, df_train_all['Date'], df_train_all['Customers'], df_train_all['Open'], df_train_all['Promo'], df_train_all['SchoolHoliday']],  axis = 1)
X
# Out:
#         Store_1  Store_2  Store_3  ...  Open  Promo  SchoolHoliday
# 76435         0        0        0  ...     0      0              0
# 923026        0        0        0  ...     1      1              1
# 731180        0        0        0  ...     1      0              0
# 790350        0        0        0  ...     1      0              1
# 252134        0        0        0  ...     1      1              0
# ...         ...      ...      ...  ...   ...    ...            ...
# 319724        0        0        0  ...     0      1              0
# 356752        0        0        0  ...     1      0              1
# 912066        0        0        0  ...     1      0              1
# 448301        0        0        0  ...     1      0              0
# 507993        0        0        0  ...     1      1              0
#
# [10000 rows x 1131 columns]

# %% [markdown]
# #5

# %%
#Calcuating the mean and std of the numerical columns from the original dataset
datemean = np.mean(df_train['Date'])
datestd  = np.std(df_train['Date'])
cusmean = np.mean(df_train['Customers'])
cusstd  = np.std(df_train['Customers'])
print(datemean, datestd, cusmean, datestd )
# Out:
# 465.0629959034967 274.4539720515303 633.1459464082602 274.4539720515303

# %%
X['Date'] = X.apply(lambda x: (X['Date'] - datemean)/datestd)
X['Customers'] = X.apply(lambda x: (X['Customers'] - cusmean)/cusstd)
X
# Out:
#         Store_1  Store_2  Store_3  ...  Open  Promo  SchoolHoliday
# 76435         0        0        0  ...     0      0              0
# 923026        0        0        0  ...     1      1              1
# 731180        0        0        0  ...     1      0              0
# 790350        0        0        0  ...     1      0              1
# 252134        0        0        0  ...     1      1              0
# ...         ...      ...      ...  ...   ...    ...            ...
# 319724        0        0        0  ...     0      1              0
# 356752        0        0        0  ...     1      0              1
# 912066        0        0        0  ...     1      0              1
# 448301        0        0        0  ...     1      0              0
# 507993        0        0        0  ...     1      1              0
#
# [10000 rows x 1131 columns]

# %%
X_tr, X_te, y_tr, y_te = train_test_split(X, df_train_all['Sales'], test_size=0.2)

print(X_tr.shape, X_te.shape,y_tr.shape, y_te.shape )
# Out:
# (8000, 1131) (2000, 1131) (8000,) (2000,)

# %% [markdown]
# # 6

# %%
from tensorflow import keras
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_log_error

class MyModel(keras.Model):
  def __init__(self, n_stores=1115, store_emb_dim=20):
    super(MyModel, self).__init__()
    self.n_stores = n_stores
    self.encoder = keras.layers.Dense(store_emb_dim, name="encoder")
    self.regressor = keras.layers.Dense(1, name="regressor")


  def call(self, X):
    x = tf.concat([self.encoder(X[:, :self.n_stores]), X[:, self.n_stores:]], axis=-1)
    return self.regressor(x)

# %%
model = MyModel()

# %%
model.compile(loss="MeanSquaredLogarithmicError", optimizer=Adam(learning_rate=0.0001), metrics=["mean_absolute_error"])

# %%
model.fit(X_tr, y_tr, validation_split=0.2, epochs=50) 
#learning rate adjusted as model trained
# Out:
# Epoch 1/50
# 200/200 [==============================] - 1s 4ms/step - loss: 3.4422 - mean_absolute_error: 3563.3113 - val_loss: 9.4997 - val_mean_absolute_error: 4072.6672
# Epoch 2/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.3255 - mean_absolute_error: 3589.6965 - val_loss: 9.4995 - val_mean_absolute_error: 4072.4980
# Epoch 3/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.4593 - mean_absolute_error: 3569.0216 - val_loss: 9.4994 - val_mean_absolute_error: 4072.1274
# Epoch 4/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.4917 - mean_absolute_error: 3704.9155 - val_loss: 9.4993 - val_mean_absolute_error: 4071.8584
# Epoch 5/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.4490 - mean_absolute_error: 3641.3549 - val_loss: 9.4992 - val_mean_absolute_error: 4071.6086
# Epoch 6/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.6129 - mean_absolute_error: 3626.5601 - val_loss: 9.4991 - val_mean_absolute_error: 4071.4465
# Epoch 7/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.4172 - mean_absolute_error: 3558.1958 - val_loss: 9.4993 - val_mean_absolute_error: 4071.1338
# Epoch 8/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.4821 - mean_absolute_error: 3624.8366 - val_loss: 9.4993 - val_mean_absolute_error: 4071.0554
# Epoch 9/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.4940 - mean_absolute_error: 3626.7679 - val_loss: 9.4995 - val_mean_absolute_error: 4070.8921
# Epoch 10/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.4101 - mean_absolute_error: 3589.7594 - val_loss: 9.4993 - val_mean_absolute_error: 4070.8269
# Epoch 11/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.3158 - mean_absolute_error: 3628.9522 - val_loss: 9.4990 - val_mean_absolute_error: 4070.7087
# Epoch 12/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.4058 - mean_absolute_error: 3591.5110 - val_loss: 9.4986 - val_mean_absolute_error: 4070.6025
# Epoch 13/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.4283 - mean_absolute_error: 3562.8817 - val_loss: 9.4984 - val_mean_absolute_error: 4070.4331
# Epoch 14/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.4044 - mean_absolute_error: 3586.8489 - val_loss: 9.4986 - val_mean_absolute_error: 4070.3218
# Epoch 15/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.3821 - mean_absolute_error: 3581.6753 - val_loss: 9.4984 - val_mean_absolute_error: 4070.3374
# Epoch 16/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.2541 - mean_absolute_error: 3637.1913 - val_loss: 9.4985 - val_mean_absolute_error: 4070.1492
# Epoch 17/50
# 200/200 [==============================] - 1s 3ms/step - loss: 3.5283 - mean_absolute_error: 3597.3426 - val_loss: 9.4985 - val_mean_absolute_error: 4070.0154
# Epoch 18/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.4053 - mean_absolute_error: 3608.0976 - val_loss: 9.4981 - val_mean_absolute_error: 4070.0740
# Epoch 19/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.3419 - mean_absolute_error: 3542.0089 - val_loss: 9.4980 - val_mean_absolute_error: 4069.9368
# Epoch 20/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.4793 - mean_absolute_error: 3612.6622 - val_loss: 9.4979 - val_mean_absolute_error: 4069.8828
# Epoch 21/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.5436 - mean_absolute_error: 3566.7411 - val_loss: 9.4976 - val_mean_absolute_error: 4069.7273
# Epoch 22/50
# 200/200 [==============================] - 1s 3ms/step - loss: 3.4553 - mean_absolute_error: 3570.0403 - val_loss: 9.4974 - val_mean_absolute_error: 4069.7458
# Epoch 23/50
# 200/200 [==============================] - 1s 3ms/step - loss: 3.3073 - mean_absolute_error: 3572.5132 - val_loss: 9.4972 - val_mean_absolute_error: 4069.6895
# Epoch 24/50
# 200/200 [==============================] - 1s 3ms/step - loss: 3.2981 - mean_absolute_error: 3465.0849 - val_loss: 9.4971 - val_mean_absolute_error: 4069.6050
# Epoch 25/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.5611 - mean_absolute_error: 3572.2100 - val_loss: 9.4968 - val_mean_absolute_error: 4069.6326
# Epoch 26/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.3484 - mean_absolute_error: 3557.4552 - val_loss: 9.4967 - val_mean_absolute_error: 4069.5190
# Epoch 27/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.4905 - mean_absolute_error: 3595.9252 - val_loss: 9.4962 - val_mean_absolute_error: 4069.4773
# Epoch 28/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.5732 - mean_absolute_error: 3486.8847 - val_loss: 9.4961 - val_mean_absolute_error: 4069.3635
# Epoch 29/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.4540 - mean_absolute_error: 3615.2914 - val_loss: 9.4958 - val_mean_absolute_error: 4069.3396
# Epoch 30/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.4129 - mean_absolute_error: 3642.5266 - val_loss: 9.4954 - val_mean_absolute_error: 4069.3579
# Epoch 31/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.4695 - mean_absolute_error: 3555.7560 - val_loss: 9.4951 - val_mean_absolute_error: 4069.2686
# Epoch 32/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.3020 - mean_absolute_error: 3608.3018 - val_loss: 9.4950 - val_mean_absolute_error: 4069.1982
# Epoch 33/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.3970 - mean_absolute_error: 3565.7741 - val_loss: 9.4945 - val_mean_absolute_error: 4069.1704
# Epoch 34/50
# 200/200 [==============================] - 1s 3ms/step - loss: 3.5523 - mean_absolute_error: 3624.7005 - val_loss: 9.4943 - val_mean_absolute_error: 4069.1521
# Epoch 35/50
# 200/200 [==============================] - 1s 3ms/step - loss: 3.4453 - mean_absolute_error: 3559.1182 - val_loss: 9.4940 - val_mean_absolute_error: 4069.1262
# Epoch 36/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.3493 - mean_absolute_error: 3529.8467 - val_loss: 9.4937 - val_mean_absolute_error: 4069.0640
# Epoch 37/50
# 200/200 [==============================] - 1s 3ms/step - loss: 3.3633 - mean_absolute_error: 3543.9047 - val_loss: 9.4937 - val_mean_absolute_error: 4069.0940
# Epoch 38/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.3819 - mean_absolute_error: 3553.2235 - val_loss: 9.4931 - val_mean_absolute_error: 4069.0674
# Epoch 39/50
# 200/200 [==============================] - 1s 3ms/step - loss: 3.4904 - mean_absolute_error: 3572.2036 - val_loss: 9.4929 - val_mean_absolute_error: 4068.9106
# Epoch 40/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.4043 - mean_absolute_error: 3588.6698 - val_loss: 9.4924 - val_mean_absolute_error: 4068.9006
# Epoch 41/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.4029 - mean_absolute_error: 3619.6393 - val_loss: 9.4922 - val_mean_absolute_error: 4068.7891
# Epoch 42/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.5091 - mean_absolute_error: 3539.3421 - val_loss: 9.4920 - val_mean_absolute_error: 4068.8389
# Epoch 43/50
# 200/200 [==============================] - 1s 3ms/step - loss: 3.3374 - mean_absolute_error: 3548.9552 - val_loss: 9.4917 - val_mean_absolute_error: 4068.7827
# Epoch 44/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.3709 - mean_absolute_error: 3600.4538 - val_loss: 9.4916 - val_mean_absolute_error: 4068.7893
# Epoch 45/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.5768 - mean_absolute_error: 3507.9925 - val_loss: 9.4912 - val_mean_absolute_error: 4068.6877
# Epoch 46/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.6229 - mean_absolute_error: 3564.4691 - val_loss: 9.4908 - val_mean_absolute_error: 4068.6287
# Epoch 47/50
# 200/200 [==============================] - 1s 3ms/step - loss: 3.2419 - mean_absolute_error: 3558.2412 - val_loss: 9.4907 - val_mean_absolute_error: 4068.6353
# Epoch 48/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.3520 - mean_absolute_error: 3621.4396 - val_loss: 9.4902 - val_mean_absolute_error: 4068.6003
# Epoch 49/50
# 200/200 [==============================] - 1s 3ms/step - loss: 3.4508 - mean_absolute_error: 3637.5061 - val_loss: 9.4900 - val_mean_absolute_error: 4068.5400
# Epoch 50/50
# 200/200 [==============================] - 0s 2ms/step - loss: 3.2942 - mean_absolute_error: 3602.3374 - val_loss: 9.4898 - val_mean_absolute_error: 4068.4910

# %%
model.summary()
# Out:
# Model: "my_model2_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder (Dense)              multiple                  11160
# _________________________________________________________________
# regressor (Dense)            multiple                  27
# =================================================================
# Total params: 11,187
# Trainable params: 11,187
# Non-trainable params: 0
# _________________________________________________________________

# %%
results = model.predict(X_te)

MSLE = np.mean((results.reshape(-1,1) - y_te.values))
print (f"Average difference between model predictions and actual sales : {MSLE}")
# Out:
# Average difference between model predictions and actual sales : -3168.2118432040215

# %% [markdown]
# The MeanSquaredLogError metric is an approprite loss function in this model because we are training our model on a continous variable.  The loss function attempts to minimize the squared log difference between the calculated sales value for a given row and the given training sales value. Other loss functions like accuracy or probability metrics would not be applicable in this sense because the predictions would give us poor values of how close or good the predictions are (probability would give 0-1 measure of how close the predicted value is to the real value and accuracy would almost always be 0 as none of the predicted values would perfectly match the the actual sales values).

# %% [markdown]
# #7

# %%
class MyModel2(keras.Model):
  def __init__(self, n_stores=1115, store_emb_dim=10):
    super(MyModel2, self).__init__()
    self.n_stores = n_stores
    self.encoder = keras.layers.Dense(store_emb_dim, name="encoder")
    self.regressor = keras.layers.Dense(1, name="regressor")

   

  def call(self, X):
    x = tf.concat([self.encoder(X[:, :self.n_stores]), X[:, self.n_stores:]], axis=-1)
    return self.regressor(x)

# %%
model2 = MyModel2()

# %%
model2.compile(loss="MeanSquaredLogarithmicError", optimizer="adam", metrics=["mean_absolute_error"])

# %%
model2.fit(X_tr, y_tr, validation_split=0.2, epochs=5)
# Out:
# Epoch 1/5
# 200/200 [==============================] - 1s 3ms/step - loss: 20.1040 - mean_absolute_error: 5741.5273 - val_loss: 19.9830 - val_mean_absolute_error: 5645.3389
# Epoch 2/5
# 200/200 [==============================] - 0s 2ms/step - loss: 19.5692 - mean_absolute_error: 5737.2627 - val_loss: 19.4910 - val_mean_absolute_error: 5641.2954
# Epoch 3/5
# 200/200 [==============================] - 0s 2ms/step - loss: 19.0720 - mean_absolute_error: 5732.8096 - val_loss: 19.0330 - val_mean_absolute_error: 5637.0762
# Epoch 4/5
# 200/200 [==============================] - 0s 2ms/step - loss: 18.6081 - mean_absolute_error: 5728.1592 - val_loss: 18.6078 - val_mean_absolute_error: 5632.6963
# Epoch 5/5
# 200/200 [==============================] - 0s 2ms/step - loss: 18.1738 - mean_absolute_error: 5723.3110 - val_loss: 18.2088 - val_mean_absolute_error: 5628.1201

# %%
model2.summary()
# Out:
# Model: "my_model2_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder (Dense)              multiple                  11160
# _________________________________________________________________
# regressor (Dense)            multiple                  27
# =================================================================
# Total params: 11,187
# Trainable params: 11,187
# Non-trainable params: 0
# _________________________________________________________________

# %%
results = model2.predict(X_te)

MSLE = (results.reshape(-1,1) - y_te.values)
print (np.mean(MSLE))
# Out:
# -5780.300213445186

# %% [markdown]
# - This is model is *not* built with `keras.models.Sequential` -- it's not simply passing data through a sequence of layers. The first 1115 columns of the input, representing the store ID, are projected onto a `store_emb_dim`-dimensional space. The resulting projections are then concatenated with the remaining features before applying linear regression. (Notice the absence of nonlinear activation functions.)
#
# - **Warning:** The data set contains > 1 million rows. To avoid running out of memory, work initially with a subset of the rows (say, 10,000). Train on as large a subset of the whole dataset as you can without crashing your session.

# %% [markdown]
# ## References
#
# Rachel Thomas, [An Introduction to Deep Learning for Tabular Data](https://www.fast.ai/2018/04/29/categorical-embeddings/) (fast.ai blog, April 29, 2018)
#
# Cheng Guo and Felix Berkhahn, [Entity Embeddings of Categorical Variables](https://arxiv.org/pdf/1604.06737.pdf) (April 25, 2016)
